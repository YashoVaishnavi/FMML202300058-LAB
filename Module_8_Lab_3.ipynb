# %% [markdown]
# <a href="https://colab.research.google.com/github/YashoVaishnavi/FMML20230058-LAB/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-17 07:13:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2024-04-17 07:13:11 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24552   1407.3969v1  Many bone shapes in the human skeleton are cha...    cs
# 22678  1704.02370v2  The Temporal Group LASSO is an example of a mu...  stat
# 11208  1501.06195v1  Kernel ridge regression (KRR) is a standard me...  stat
# 10396   1306.1185v1  Ideas from the image processing literature hav...  stat
# 38169   1305.0194v1  Many recent works aim at developing methods an...    cs
# ...             ...                                                ...   ...
# 32185   1206.4630v1  Structured prediction is the cornerstone of se...    cs
# 21837   1305.0319v6  Dasgupta and Shulman showed that a two-round v...  stat
# 11385  1511.09159v1  The Support Vector Machine (SVM) has been used...  stat
# 15978  1607.07565v1  This paper presents a computational model of t...    cs
# 29398  1709.02926v2  In view of contemporary panoramic camera-laser...    cs
#
#                                                    title  year  \
# 24552  An iterative approach to Hough transform witho...  2014
# 22678  A Brief Introduction to the Temporal Group LAS...  2017
# 11208  Randomized sketches for kernels: Fast and opti...  2015
# 10396              Multiclass Total Variation Clustering  2013
# 38169  MATAWS: A Multimodal Approach for Automatic WS...  2013
# ...                                                  ...   ...
# 32185  Efficient Decomposed Learning for Structured P...  2012
# 21837  Learning Mixtures of Bernoulli Templates by Tw...  2013
# 11385  Proximal gradient method for huberized support...  2015
# 15978  Grounding Dynamic Spatial Relations for Embodi...  2016
# 29398  Joint Calibration of Panoramic Camera and Lida...  2017
#
#                                                 keywords
# 24552  [characterized, associated, equations, algebra...
# 22678  [regularized, regression, prediction, variable...
# 11208  [regression, performing, parametric, regressio...
# 10396  [processing, literature, motivated, clustering...
# 38169  [developing, processing, appropriate, benchmar...
# ...                                                  ...
# 32185  [structured, prediction, cornerstone, applicat...
# 21837  [algorithm, distributions, precision, probabil...
# 11385  [classification, differentiable, difficult, pa...
# 15978  [computational, processing, relations, occurri...
# 29398  [contemporary, panoramic, traditional, calibra...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24552    [characterized, associated, equations, algebra...
# 22678    [regularized, regression, prediction, variable...
# 11208    [regression, performing, parametric, regressio...
# 10396    [processing, literature, motivated, clustering...
# 38169    [developing, processing, appropriate, benchmar...
#                                ...
# 12492    [convolutional, increasingly, attention, proce...
# 37889    [classification, unlabeled, functional, discus...
# 22282    [equations, implement, variational, estimation...
# 29524    [applications, ophthalmology, assistive, techn...
# 10605    [screening, irrelevant, variables, optimizatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8816 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="30e99414-3e4a-4d8d-aecf-a92b45cbced6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30e99414-3e4a-4d8d-aecf-a92b45cbced6")) {                    Plotly.newPlot(                        "30e99414-3e4a-4d8d-aecf-a92b45cbced6",                        [{"x":["algebraic","recognition","efficient","iterative","associate","transform","parameters","different","equations","characterized","technique","classical","accurately","piecewise","collection","continuously","procedure","described","associated","describing","variables","regularized","potential","attractive","regression","introduction","predictors","prediction","applications","simplicity","healthcare","introduce","overfitting","parametric","reproducing","performing","approximations","complexity","dimension","respectively","dimensional","approximate","proportional","projection","computing","logarithmic","optimality","prohibitive","including","preserving","statistical","randomized","extensions","algorithms","literature","multiclass","motivated","partitioning","clustering","outperform","approaches","framework","processing","recursion","variation","recursive","resampled","operations","semantically","automatic","automation","descriptions","association","efficiency","advantage","processed","appropriate","structures","annotation","realistic","collections","generated","benchmark","semantics","syntactic","parameter","performed","developing","available","multimodal","experiment","integrated","complementary","discriminator","representations","utilization","convolutional","motivation","performance","introduced","segmentation","promotion","effective","particular","additionally","corresponding","extracting","visualization","enhancing","classifier","restricted","successfully","configuration","embedding","techniques","resulting","intrinsic","advertising","programming","dimensionality","recommendation","interfaces","identified","dimensions","placement","continuous","intelligent","optimization","embeddings","important","successes","empirical","categorical","theoretical","algorithm","properties","optimizing","invariance","effectively","promising","introduces","maintaining","investigation","imperative","solutions","implementation","individuals","maintains","constructive","premature","designing","simulation","functions","suboptimal","landscape","understanding","evolutionary","population","convergence","diversity","comprehensive","generalize","datamodel","selecting","computational","combinations","explicitly","geometric","standalone","subspaces","discriminative","classification","architectures","orthogonal","simultaneously","collapsed","significantly","similarity","naturally","demonstrate","carefully","ubiquitous","profitable","equipping","idealistic","offspring","selection","surprisingly","combinatorial","instances","correlation","adjusting","distinguish","satisfiable","intermediate","asymptotic","intersection","represents","resultant","alternately"],"y":[14,399,396,84,9,65,252,765,26,28,243,91,64,14,79,15,126,50,108,37,138,41,143,20,118,22,7,231,420,16,12,345,22,36,7,83,29,194,57,79,179,104,7,52,140,18,30,7,220,59,136,27,38,612,128,9,68,5,152,93,435,576,308,4,64,21,2,88,27,191,16,46,33,142,93,30,96,145,69,67,24,190,210,94,48,121,130,57,303,38,70,65,39,13,225,9,361,25,918,141,219,1,260,260,62,134,78,20,26,148,53,91,21,116,410,149,42,6,115,43,30,17,43,41,6,97,55,334,78,362,11,143,7,165,809,198,37,23,112,127,72,40,32,4,169,126,38,13,8,4,48,84,204,14,13,148,65,58,130,42,72,44,2,47,284,39,78,71,7,24,108,480,107,25,117,2,268,146,54,580,25,17,3,2,1,8,150,27,42,95,72,5,28,3,29,16,11,40,12,3],"type":"bar"},{"x":["algebraic","recognition","efficient","iterative","associate","transform","parameters","di ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style=''>k</span> <span style=''>way</span> <span style=''>Co</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>occurrences</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embeddings</span> <br/><br/><span style=''>Co</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>occurrences</span> <span style=''>between</span> <span style=''>two</span> <span style=''>words</span> <span style=''>provide</span> <span style=''>useful</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.9381443298969072);'>semantics</span> <span style=''>of</span> <span style=''>those</span> <span style=''>words</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>numerous</span> <span style=''>prior</span> <span style=''>work</span> <span style=''>on</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>learning</span> <span style=''>have</span> <span style=''>used</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>occurrences</span> <span style=''>between</span> <span style=''>two</span> <span style=''>words</span> <span style=''>as</span> <span style=''>the</span> <span style=''>training</span> <span style=''>signal</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>However</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>texts</span> <span style=''>it</span> <span style=''>is</span> <span style=''>common</span> <span style=''>for</span> <span style=''>multiple</span> <span style=''>words</span> <span style=''>to</span> <span style=''>be</span> <span style=''>related</span> <span style=''>and</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>occurring</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style=''>context</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>occurrences</span> <span style=''>to</span> <span style=''>cover</span> <span style=''>k(geq2)</span> <span style=''>way</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>occurrences</span> <span style=''>among</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>k</span> <span style=''>words</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>k(geq2)</span> <span style=''>words</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>ell</span> <span style=''>2</span> <span style=''>norms</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>Next</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Group</span> <span style=''>Sparse</span> <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Active</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surveillance</span> <span style=''>on</span> <span style=''>Epidemic</span> <span style=''>Dynamics</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>epidemic</span> <span style=''>dynamics</span> <span style=''>is</span> <span style=''>of</span> <span style=''>great</span> <span style=''>value</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>controlling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>infectious</span> <span style=''>disease</span> <span style=''>spread</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>This</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surveillance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>are</span> <span style=''>very</span> <span style=''>limited</span> <span style=''>To</span> <span style=''>address</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>active</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surveillance</span> <span style=''>ie</span> <span style=''>how</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>a</span> <span style=''>small</span> <span style=''>portion</span> <span style=''>of</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>as</span> <span style=''>sentinels</span> <span style=''>to</span> <span style=''>effect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style=''>epidemic</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>an</span> <span style=''>entire</span> <span style=''>system</span> <span style=''>can</span> <span style=''>be</span> <span style=''>readily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>from</span> <span style=''>the</span> <span style=''>partial</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>by</span> <span style=''>such</span> <span style=''>sentinels</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>gamma</span> <span style=''>value</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>the</span> <span style=''>sentinels</span> <span style=''>by</span> <span style=''>modeling</span> <span style=''>a</span> <span style=''>sentinel</span> <span style=''>network</span> <span style=''>with</span> <span style=''>row</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>We</span> <span style=''>design</span> <span style=''>a</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>in</span> <span style=''>random</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>graphs</span> <br/><br/><span style=''>Consider</span> <span style=''>a</span> <span style=''>weighted</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unweighted</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>graph</span> <span style=''>that</span> <span style=''>has</span> <span style=''>been</span> <span style=''>built</span> <span style=''>on</span> <span style=''>n</span> <span style=''>data</span> <span style=''>points</span> <span style=''>drawn</span> <span style=''>randomly</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>according</span> <span style=''>to</span> <span style=''>some</span> <span style=''>density</span> <span style=''>p</span> <span style=''>on</span> <span style=''>Rd</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>in</span> <span style=''>such</span> <span style=''>graphs</span> <span style=''>as</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>infinity</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unweighted</span> <span style=''>kNN</span> <span style=''>graphs</span> <span style=''>this</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>an</span> <span style=''>unpleasant</span> <span style=''>distance</span> <span style=''>function</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>space</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>detrimental</span> <span style=''>to</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>also</span> <span style=''>study</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>in</span> <span style=''>weighted</span> <span style=''>kNN</span> <span style=''>graphs</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>Multi</span> <span style=''>class</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Acute</span> <span style=''>Oral</span> <span style=''>Toxicity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style=''>Chemical</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extraction</span> <br/><br/><span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>property</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>(QSPR)</span> <span style=''>studies</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>chemoinformatics</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>to</span> <span style=''>get</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>chemical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>chemical</span> <span style=''>features</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style=''>QSPR</span> <span style=''>models</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>A</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecular</span> <span style=''>graph</span> <span style=''>encoding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(MGE</span> <span style=''>CNN)</span> <span style=''>provided</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universal</span> <span style=''>strategy</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>QSPR</span> <span style=''>models</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>specific</span> <span style=''>preset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>descriptors</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fingerprints</span> <span style=''>the</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08374910905203137)
# 	representation (0.12223806129722024)
# 	processing (0.1097647897362794)
# 	experimental (0.14112615823235922)
# 	detection (0.12437633642195296)
# 	segmentation (0.07804704205274413)
# 	information (0.2608695652173913)
# 	different (0.27263007840342124)
# 	convolutional (0.1286528866714184)
# 	recognition (0.1421952957947256)
#
# Some Statistics words are:
# 	stochastic (0.1354062186559679)
# 	theoretical (0.15095285857572718)
# 	variables (0.1424272818455366)
# 	estimation (0.1715145436308927)
# 	algorithm (0.3901705115346038)
# 	distribution (0.1770310932798395)
# 	statistical (0.15997993981945838)
# 	inference (0.19307923771313942)
# 	dimensional (0.1900702106318957)
# 	regression (0.19157472417251756)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7ef8033a-0479-4557-8432-2f2d086c76e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ef8033a-0479-4557-8432-2f2d086c76e0")) {                    Plotly.newPlot(                        "7ef8033a-0479-4557-8432-2f2d086c76e0",                        [{"x":["algebraic","recognition","efficient","iterative","associate","transform","parameters","different","equations","characterized","technique","classical","accurately","piecewise","collection","continuously","procedure","described","associated","describing","variables","regularized","potential","attractive","regression","introduction","predictors","prediction","applications","simplicity","healthcare","introduce","overfitting","parametric","reproducing","performing","approximations","complexity","dimension","respectively","dimensional","approximate","proportional","projection","computing","logarithmic","optimality","prohibitive","including","preserving","statistical","randomized","extensions","algorithms","literature","multiclass","motivated","partitioning","clustering","outperform","approaches","framework","processing","recursion","variation","recursive","resampled","operations","semantically","automatic","automation","descriptions","association","efficiency","advantage","processed","appropriate","structures","annotation","realistic","collections","generated","benchmark","semantics","syntactic","parameter","performed","developing","available","multimodal","experiment","integrated","complementary","discriminator","representations","utilization","convolutional","motivation","performance","introduced","segmentation","promotion","effective","particular","additionally","corresponding","extracting","visualization","enhancing","classifier","restricted","successfully","configuration","embedding","techniques","resulting","intrinsic","advertising","programming","dimensionality","recommendation","interfaces","identified","dimensions","placement","continuous","intelligent","optimization","embeddings","important","successes","empirical","categorical","theoretical","algorithm","properties","optimizing","invariance","effectively","promising","introduces","maintaining","investigation","imperative","solutions","implementation","individuals","maintains","constructive","premature","designing","simulation","functions","suboptimal","landscape","understanding","evolutionary","population","convergence","diversity","comprehensive","generalize","datamodel","selecting","computational","combinations","explicitly","geometric","standalone","subspaces","discriminative","classification","architectures","orthogonal","simultaneously","collapsed","significantly","similarity","naturally","demonstrate","carefully","ubiquitous","profitable","equipping","idealistic","offspring","selection","surprisingly","combinatorial","instances","correlation","adjusting","distinguish","satisfiable","intermediate","asymptotic","intersection","represents","resultant","alternately","propositions","expressed","incorporation","conditional","preliminary","knowledge","maximization","mentioned","consistently","integrity","constraints","incorporate","consistency","extension","informally","formulation","languages","connection","distributions","difference","augmentation","effectiveness","extensive","intractable","controlling","successful","generalized","minimizes","artificially","exploring","supervised","corrupting","iteratively","expectation","thoroughly","locations","detection","comparison","environments","uncertainty","baselines","experimental","information","exploiting","evaluated","existence","considering","localization","synthetic","estimating","arbitrary","estimation","essentially","noiseless","identification","interaction","a ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	lancaster
# 	underestimated
# 	instantiating
# 	debiasing
# 	unmeasured
# 	triangular
# 	ensembling
# 	pretreatment
# 	recasting
# 	percentile
# 	subsampling
# 	reciprocity
# 	martingale
# 	chemoinformatics
# 	therapies
# 	elucidating
# 	emphdirectly
# 	expectimax
# 	undetermined
# 	regressionclassification
# Some words which never appear in Statistics papers:
# 	premature
# 	datamodel
# 	equipping
# 	offspring
# 	satisfiable
# 	alternately
# 	propositions
# 	integrity
# 	reservoir
# 	reordering
# 	scrutinized
# 	filterbank
# 	attentional
# 	humanities
# 	manipulation
# 	specifications
# 	hierarchal
# 	eligibility
# 	requested
# 	intracranial

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0662619200932145e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7733333333333333
